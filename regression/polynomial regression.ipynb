# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures as pf
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
train_data=pd.read_csv(r"C:\Users\pawan_300\Desktop\Project work\ml lab assignmnet\train.csv")
test_data=pd.read_csv(r"C:\Users\pawan_300\Desktop\Project work\ml lab assignmnet\test.csv")

# %%
train_data
# Out:
#         AT      V       AP     RH      PE
# 0     8.34  40.77  1010.84  90.01  480.48
# 1    23.64  58.49  1011.40  74.20  445.75
# 2    29.74  56.90  1007.15  41.91  438.76
# 3    19.07  49.69  1007.22  76.79  453.09
# 4    11.80  40.66  1017.13  97.20  464.43
# 5    13.97  39.16  1016.05  84.60  470.96
# 6    22.10  71.29  1008.20  75.38  442.35
# 7    14.47  41.76  1021.98  78.41  464.00
# 8    31.25  69.51  1010.25  36.83  428.77
# 9     6.77  38.18  1017.80  81.13  484.31
# 10   28.28  68.67  1006.36  69.90  435.29
# 11   22.99  46.93  1014.15  49.42  451.41
# 12   29.30  70.04  1010.95  61.23  426.25
# 13    8.14  37.49  1009.04  80.33  480.66
# 14   16.92  44.60  1017.34  58.75  460.17
# 15   22.72  64.15  1021.14  60.34  453.13
# 16   18.14  43.56  1012.83  47.10  461.71
# 17   11.49  44.63  1020.44  86.04  471.08
# 18    9.94  40.46  1018.90  68.51  473.74
# 19   23.54  41.10  1002.05  38.05  448.56
# 20   14.90  52.05  1015.11  77.33  464.82
# ...

# %%
test_data
# Out:
#         AT      V       AP      RH      PE
# 0     8.67  40.77  1011.81   89.40  479.23
# 1    10.53  37.50  1008.55   99.91  472.32
# 2     7.99  41.38  1021.95   78.77  487.57
# 3    22.29  45.01  1012.40   51.58  449.08
# 4     9.06  36.30  1015.14   58.71  477.38
# 5    10.05  37.14  1012.64   75.97  474.16
# 6    20.07  49.21  1012.34   56.80  454.25
# 7    30.65  71.98  1004.92   63.39  429.85
# 8    14.38  40.73  1017.48   90.64  462.98
# 9    27.76  71.97  1008.53   86.97  434.04
# 10   16.70  40.56  1019.04   50.90  470.84
# 11    5.35  35.57  1027.12   80.81  488.65
# 12   11.57  41.38  1021.71   61.49  473.94
# 13   30.57  73.03  1013.75   73.68  437.42
# 14   16.00  40.66  1016.12   89.23  457.12
# 15   15.60  41.04  1025.48   64.43  457.49
# 16   22.12  47.93  1005.50   84.47  443.41
# 17   21.33  58.46  1016.17   79.73  445.27
# 18   23.65  59.92  1010.19   89.53  436.74
# 19    6.80  39.37  1020.24   73.29  487.33
# 20   31.35  71.32  1005.99   62.35  434.43
# ...

# %%
train=train_data.values
test=test_data.values
y=np.matrix(train[:,4])
m=train_data.count()[0]
x=polynomial(train[:,0:4])
y_actual=test[:,4]

# %%
def polynomial(data):
    p=pf(2)    # This is polynomial of degree two 
    x=p.fit_transform(data)
    return(x)

# %%
def regression(n):
    theta=np.matrix([0]*x.shape[1])
    err=[]
    for i in range(n):
        y0=x.dot(theta.T)
        e=y.T-y0
        err.append(1/(2*m)*(np.sum(np.square(e))))
        if((err[i])<0.00001):
            break
        else:
            theta=gradient(theta,y0)
    ploterror(err)
    return(theta)

# %%
def gradient(theta,y0):
        alpha=0.0000000000001
        z=alpha/m
        theta=theta.T-(z*((y0-np.matrix(y.T)).T.dot(x)).T)
        return(theta.T)

# %%
def solution(n):
    theta=regression(n)
    y=polynomial(test[:,0:4])
    return(y.dot(theta.T))

# %%
def error(n):
    prediction=solution(n)
    z=prediction-y_actual
    return(math.sqrt(mean_squared_error(y_actual,prediction)))

# %%
def ploterror(err):
    print("Plot between error and number of iteration is :")
    plt.plot([i for i in range(len(err))],err)

# %%
error(1000)
# Out:
# Plot between error and number of iteration is :
# 14.539741171316033
